# %%
from dotenv import load_dotenv

# %%
# Load env variables

if load_dotenv():
    print("Environment variables loaded.")
else:
    print("No .env file found or failed to load.")
# Out:
# Environment variables loaded.

# %%
from langchain_openai import ChatOpenAI

gpt4o_chat = ChatOpenAI(model="gpt-4o", temperature=0)
response = gpt4o_chat.invoke("Hello, world!")

print(response)
# Out:
# c:\Users\msund\anaconda3\envs\paam\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ...

# %%
from langchain_tavily import TavilySearch

tavily_search = TavilySearch(max_results=3)
search_docs = tavily_search.invoke("Get me the latest news on AI")

print(search_docs)
# Out:
# c:\Users\msund\anaconda3\envs\paam\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "output_schema" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# c:\Users\msund\anaconda3\envs\paam\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "stream" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# ...

# %%
from langchain_ollama import ChatOllama

gemma_chat = ChatOllama(model="llama3.1:8b", temperature=0)
response = gemma_chat.invoke("Hello, world!")

print(response)
# Out:
# content="Hello! It's nice to meet you. Is there something I can help you with or would you like to chat?" additional_kwargs={} response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-04-12T07:34:28.102522Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512611400, 'load_duration': 62555400, 'prompt_eval_count': 14, 'prompt_eval_duration': 240721700, 'eval_count': 25, 'eval_duration': 195707400, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'} id='lc_run--019d809d-0600-7982-a054-1187fb17dff4-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 14, 'output_tokens': 25, 'total_tokens': 39}
