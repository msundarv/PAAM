# %% [markdown]
# #### Ref: https://github.com/alexprengere/currencyconverter

# %%
from currency_converter import CurrencyConverter, ECB_URL, SINGLE_DAY_ECB_URL

# %%
ECB_URL
# Out:
# 'https://www.ecb.europa.eu/stats/eurofxref/eurofxref-hist.zip'

# %%
SINGLE_DAY_ECB_URL
# Out:
# 'https://www.ecb.europa.eu/stats/eurofxref/eurofxref.zip'

# %%
c = CurrencyConverter(SINGLE_DAY_ECB_URL)

print("100 USD = ", round(c.convert(100, "USD", "SGD"), 2), "SGD")
print("100 SGD = ", round(c.convert(100, "SGD", "SGD"), 2), "SGD")
print("100 EUR = ", round(c.convert(100, "EUR", "SGD"), 2), "SGD")
print("100 CAD = ", round(c.convert(100, "CAD", "SGD"), 2), "SGD")
print("100 INR = ", round(c.convert(100, "INR", "SGD"), 2), "SGD")
# Out:
# 100 USD =  128.71 SGD
# 100 SGD =  100.0 SGD
# 100 EUR =  148.34 SGD
# 100 CAD =  92.54 SGD
# 100 INR =  1.38 SGD
